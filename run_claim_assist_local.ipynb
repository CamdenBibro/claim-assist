# %% [markdown]
# <a href="https://colab.research.google.com/github/CamdenBibro/claim-assist/blob/kxu-dev-01/run_claim_assist_local.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Setup

# %%
# !apt-get update
# !apt-get install -y chromium-chromedriver
# !apt-get install -y chromium-browser

# !which chromedriver
# !ls -la /usr/bin/chromedriver
# !ls -la /usr/bin/chromium-browser
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,157 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# !chromedriver --version
# Out:
# Command '/usr/bin/chromedriver' requires the chromium snap to be installed.
# Please install it with:
#
# snap install chromium

# %%
# !git clone https://github.com/CamdenBibro/claim-assist.git
# Out:
# Cloning into 'claim-assist'...
# remote: Enumerating objects: 191, done.
# remote: Counting objects: 100% (191/191), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 191 (delta 76), reused 157 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (191/191), 156.00 KiB | 1.26 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# %cd claim-assist
# !git commit -m "fix-simple issue from researcher"
# %cd ..
# Out:
# /content/claim-assist
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@66c4357c6b2a.(none)')
# /content

# %%
# %cd claim-assist
# !git checkout kxu-dev-01
# %cd ..
# Out:
# /content/claim-assist
# Branch 'kxu-dev-01' set up to track remote branch 'kxu-dev-01' from 'origin'.
# Switched to a new branch 'kxu-dev-01'
# /content

# %%
# !pip -q install llama-cpp-python \
  --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu124
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 551.3/551.3 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.9 MB/s eta 0:00:00

# %%
# !pip -q install selenium undetected-chromedriver
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 116.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.0/512.0 kB 40.2 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import hf_hub_download

path = hf_hub_download(
    repo_id="bartowski/Meta-Llama-3.1-8B-Instruct-GGUF",
    filename="Meta-Llama-3.1-8B-Instruct-Q4_K_M.gguf"
)
print("Downloaded to:", path)
# Out:
# Meta-Llama-3.1-8B-Instruct-Q4_K_M.gguf:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Downloaded to: /root/.cache/huggingface/hub/models--bartowski--Meta-Llama-3.1-8B-Instruct-GGUF/snapshots/bf5b95e96dac0462e2a09145ec66cae9a3f12067/Meta-Llama-3.1-8B-Instruct-Q4_K_M.gguf

# %%
# %cd /content/claim-assist
# !pip -q install -r requirements.txt
# Out:
# /content/claim-assist
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.2/388.2 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.3/252.3 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 5.9 MB/s eta 0:00:00

# %%
import os
os.environ['INFERENCE_BACKEND'] = 'llamacpp_python'
os.environ['MODEL_PATH'] = path
os.environ['N_GPU_LAYERS'] = '50'
os.environ['ENABLE_SELENIUM'] = 'false'

# %%
# %cd claim-assist
# Out:
# [Errno 2] No such file or directory: 'claim-assist'
# /content/claim-assist

# %%
# %cd /content/claim-assist
# !python -m claim_assist.main /content/claim-assist/sample/input/example_claims.csv
# Out:
# /content/claim-assist
# Initializing Claim Assist processor with llamacpp_python backend...
# Using model: llama-3.1-8b-instruct
# Model path: /root/.cache/huggingface/hub/models--bartowski--Meta-Llama-3.1-8B-Instruct-GGUF/snapshots/bf5b95e96dac0462e2a09145ec66cae9a3f12067/Meta-Llama-3.1-8B-Instruct-Q4_K_M.gguf
# GPU layers: 50
# llama_context: n_ctx_per_seq (4096) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# Processing claims from: /content/claim-assist/sample/input/example_claims.csv
# Processing 10 items...
# Processing claims:   0% 0/10 [00:00<?, ?item/s]🔍 Searching for comparable prices using 3 queries...
#    Searching: 'Samsung 55-inch 4K TV'
#    Found 9 results
#       - eBay: $445.60 - Samsung 55 inch Class Q7F Series QLED 4K Vision AI
#       - eBay: $547.60 - Samsung 55 inch Class Q8F Series QLED 4K UHD HDR S
#       - eBay: $627.60 - Samsung 55 inch QN70F 4K Smart TV QLED HDR 120Hz (
#    Searching: 'Samsung Samsung 55-inch 4K TV'
# ...
